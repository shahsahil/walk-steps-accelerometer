# %%
import pandas as p
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
walk=p.read_csv('C:\\Users\\Sahil\\Desktop\\walk.csv',sep=',')

# %%
len(walk)
# Out:
# 1693

# %%
plt.plot(walk[300:420]['x'])
plt.plot( walk[300:420]['y'])
plt.plot(walk[300:420]['z'])
plt.show()

# %%
rand=p.read_csv('C:\\Users\\Sahil\\Desktop\\sahilacc.csv',sep=',')
plt.plot(rand[22000:39000]['x'])
plt.plot(rand[22000:39000]['y'])
plt.plot(rand[22000:39000]['z'])
plt.show()

# %%
import numpy as np
#np.correlate()
for i in range(22000, 38000):
    X = np.corrcoef(walk[300:420]['x'], rand[i:i+120]['x'])[0][1]
    Y = np.corrcoef(walk[300:420]['y'], rand[i:i+120]['y'])[0][1]
    Z = np.corrcoef(walk[300:420]['z'], rand[i:i+120]['z'])[0][1]
    if(X>0.7 and Y>0.7 and Z>0.7):
        print(str(i)+" walk "+str(X))
# Out:
# 22782 walk 0.715574643826
# 25803 walk 0.712270498253
# 25804 walk 0.734964108517
# 25805 walk 0.715852027652
# 25941 walk 0.807313931852
# 25942 walk 0.76696369411
# 26776 walk 0.709556977894
# 26777 walk 0.756454302742
# 26778 walk 0.749549527581
# 26911 walk 0.73919273777
# 26912 walk 0.821983744556
# 26913 walk 0.852240579919
# 26914 walk 0.817062255136
# 26915 walk 0.72933090789
# 27049 walk 0.704203506159
# 27317 walk 0.704913347262
# 27318 walk 0.711375027825
# 27588 walk 0.757569468374
# 27589 walk 0.778123322126
# 27590 walk 0.748411227718
# 27722 walk 0.700462860326
# 27723 walk 0.74085845004
# 27724 walk 0.737116601547
# 27989 walk 0.700745181012
# 27990 walk 0.736290925598
# 27991 walk 0.734623411624
# 28125 walk 0.724105877739
# 28126 walk 0.730259835515
# 28391 walk 0.702667847162
# 29064 walk 0.740983153457
# 29065 walk 0.724491161008
# 29335 walk 0.741931376398
# 29336 walk 0.715787809867
# 29904 walk 0.70069817789
# 30477 walk 0.701738838489
# ...
